# %%
N=int(input("Enter the value for the rang of n :  /n"))
print("N =",(N))
i=int(input("Enter the value of power of n :  /n"))
print("i =",(i))
sum = 0
for n in (1,N+1):
   sum+=n**i
print(sum)
# Out:
# Enter the value for the rang of n :  /n5
# N = 5
# Enter the value of power of n :  /n2
# i = 2
# 37
